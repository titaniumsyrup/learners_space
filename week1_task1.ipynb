# %% [markdown]
# <a href="https://colab.research.google.com/github/titaniumsyrup/learners_space/blob/week1/week1_task1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Numpy Implementation

# %%
import numpy as np
# Create a 2D Numpy array of size 1x3 with elements of your choice
arr1=np.array([[1,2,3]])#Your code here

# Create a Numpy array of length 50 with zeroes as its elements
arr2=np.zeros(50)#Your code here

#Create a Numpy array of length 3x2 with elements of your choice
arr3=np.array([[1,2],[3,4],[4,5]])#Your code here

arr4=np.dot(arr1 ,arr3)#Multiply arr1 and arr3 using Numpy functions

#Change 5th element of arr2 to a different number
#Your code here
arr2[4]=3

if np.shape(arr4)==(1,2) and arr2[4]!=0:
  print("Passed")
else:
  print("Fail")
# Out:
# Passed

# %%
import numpy as np
x=np.identity(3)
y=9*x+1
print(np.dot(x,y))
#Task: Perform the dot product of I and 9I+1 using numpy, here I is referred to as an 3x3 Identity matrix.
# Out:
# [[10.  1.  1.]
#  [ 1. 10.  1.]
#  [ 1.  1. 10.]]

# %% [markdown]
# # Pandas Implementation

# %%
import pandas as pd

## Create a DataFrame from a dictionary
data = {
    'Name': ['Ramesh', 'Mahesh', 'Suresh'],
    'Age': [25, 30, 35],
    'City': ['Bangalore', 'Mumbai', 'Delhi']
}
#Your code here
df=pd.DataFrame(data)
#Display the first 2 rows of the data frame
#Your code here
print(df.head(2))
#Print the age column
#Your code here
print(df['Age'])
#Filter rows where age is greater than 26
#Your code here
filtered_df = df[df['Age'] > 26]
#Add a new column 'Country' with the value 'India' for all rows
#Your code here
df['Country'] = 'India'
data1 = {
    'Name': ['Ramesh', 'Mahesh', 'Suresh'],
    'Age': [25, None, 35],
    'City': ['Bangalore', 'Mumbai', 'Delhi']
}

df2= pd.DataFrame(data1)

# Fill missing values in the 'Age' column with the mean age
#Your code here
mean_age = df['Age'].mean()
df['Age'].fillna(mean_age, inplace=True)
# Out:
#      Name  Age       City
# 0  Ramesh   25  Bangalore
# 1  Mahesh   30     Mumbai
# 0    25
# 1    30
# 2    35
# Name: Age, dtype: int64

# %% [markdown]
# # Matplotlib Implementation

# %%
import matplotlib.pyplot as plt
import numpy as np



xpoints=np.array([1,2,3,4])
ypoints=np.array([2,4,6,8])

#Plot these points without drawing a line
#Your code here
plt.scatter(xpoints, ypoints)
#plt.show()
#Plotting with marker: Plot these points with a marker(Star marker)
#Your code here
plt.scatter(xpoints, ypoints, marker='*')
#plt.show()
#Using fmt format, add circular marker,red color and Dashed line
#Your code here
plt.plot(xpoints, ypoints, 'ro--')
#plt.show()
#Add xlabel,ylabel and title for the plot.
#Your code here
plt.scatter(xpoints, ypoints)
plt.xlabel('X-axis')
plt.ylabel('Y-axis')
plt.title('Scatter Plot')
#Create a scatter plot for xpoints and ypoints
#Your code here
plt.scatter(xpoints, ypoints)
#plt.show()
#Set color to the scatter plot. Blue,Green,Red and yellow color for each point respectively
colors = ['b', 'g', 'r', 'y']
plt.scatter(xpoints, ypoints, c=colors)
#plt.show()

# %% [markdown]
# # Miscellaneous Modules Implementation

# %%
import random
import numpy as np

#Set the seed of random to 20
random.seed(20)
#Your code here

arr1=np.array([1,24,31,45,73,81,94,25])

#Using the random module pick 4 different random numbers from arr1 and return their sum.
#Your code here
random_numbers = random.sample(list(arr1), 4)
sum_of_random_numbers = sum(random_numbers)
print("Randomly picked numbers:", random_numbers)
print("Sum of randomly picked numbers:", sum_of_random_numbers)
# Out:
# Randomly picked numbers: [31, 25, 81, 1]
# Sum of randomly picked numbers: 138
